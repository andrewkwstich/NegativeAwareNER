# %%
import pandas as pd
import json
from pandas import json_normalize
import gzip

# %%
import pandas as pd

attributes = {}
def getDF(path):
    i = 0
    df = {}
    for d in open(path):
        json_str = json.loads(d)
        if "style" not in json_str:
            continue
        for k,v in json_str["style"].items():
            if k not in attributes:
                attributes[k] = set()
            attributes[k].add(v.strip()) 
        if 'reviewText' not in json_str:
            continue
        df[i] = json_str["reviewText"]
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

df_home = getDF('../data/Home_and_Kitchen_5.json')
df_tools = getDF('../data/Tools_and_Home_Improvement_5.json')

# %%
df_home.to_csv('../data/reviews_home.csv')

# %%
df_tools.to_csv('../data/reviews_tools.csv')

# %%
attributes.keys()
# Out:
# dict_keys(['Color:', 'Format:', 'Style Name:', 'Size:', 'Material Type:', 'Package Quantity:', 'Size Name:', 'Style:', 'Item Package Quantity:', 'Item Display Length:', 'Length:', 'Package Type:', 'Design:', 'Item Display Weight:', 'Product Packaging:', 'Number of Items:', 'Flavor:', 'Flavor Name:', 'Color Name:', 'Scent Name:', 'Display Height:', 'Pattern:', 'Shape:', 'Scent:', 'Team Name:', 'Outside Diameter:', 'Overall Length:', 'Model Name:', 'Model Number:', 'Item Weight:', 'Material:', 'Configuration:', 'Curvature:', 'style:', 'Edition:', 'Denomination:', 'Colour:', 'Offer Type:', 'Wattage:', 'Overall Width:', 'Part Number:', 'Thickness:', 'Line Weight:', 'Item Shape:', 'Gauge:', 'Hand Orientation:', 'Inside Diameter:', 'Connector Type:', 'Volume:', 'Capacity:', 'Bore Diameter:', 'Model:', 'Grit Type:'])

# %%
attributes["Color:"]
# Out:
# {'',
#  'Multiple Hammer Gold',
#  'Oil Rubbed Bronze 10',
#  'Hanging Hamper',
#  '15',
#  'Circle,dark Gray',
#  'S30 (8.25") Hedgehog Green Mixing Bowl',
#  '1200 lumen - B',
#  '12v 2a Power Supply',
#  'The Witching Hour',
#  'Twine',
#  'Teal/Purple Poof',
#  'All About Dots',
#  '4x-YK-B106(013-016)',
#  'Soft Taupe',
#  'Wine',
#  'Green Heron',
#  'Summer Olaf',
#  'Sol Orange Matte',
#  'T Shirt Folder',
#  'Silver Geometric',
#  'HEAVY',
#  'Mina Emb Blue',
#  'White*2pcs',
#  'Floral Green',
#  'Navy/Tan',
#  '23. the Ten Commandments',
#  'Dog Head',
#  'Taupe',
#  'QD-Rose Gold',
#  'Cs08 Color Green',
#  'Purple Circle Graphic',
#  '500222201c50a 4x6 2-opening - 1" Border',
#  'Lotion Dispense',
#  '3PC-SilverWire-Yellow',
#  'Tropical Scents',
#  'Curve Square',
#  'Black Knot',
#  '10 ounce',
#  'Vine Silver',
#  'style 23',
#  'Mandala Flower - Burgundy',
#  'Black-red',
#  'Escape',
#  'SD02',
#  'Carolina Fields',
#  'Black with Purple sequins',
#  '6 PCS 2835 3528 Single Color Led Light Strip Connector',
#  'Pure White(3201K)',
#  'Groovy',
#  '#1-rose Quartz Lotus Flower 2"',
#  'Mod Green',
#  'Greenwithstoragebox',
#  'Weathered White',
#  's1',
#  '3 Assorted Scents',
#  'Blue Desk',
#  'Bamboo with Condensation Trap',
#  'Platinum Stainless Steel',
#  'Elec02 Version',
#  'Fuchisa/Navy',
#  'Matte Black CXRi',
#  'Gold/Ivory',
#  'Dark Purple 4pcs',
#  '5x 6000K',
#  'I Make Beer Disappear',
#  'Virtual Mist',
#  'Fur Purple',
#  '6 Cavity',
#  'Fresh Mint',
#  'Star Shape Ice Cubes',
#  'Metallic Nickel',
#  'Gingham',
#  'Sand Fabric',
#  'Purple to Orange',
#  'Pink Rabbit',
#  'Navy / Grey / White',
#  'KD14029',
#  'Silver 25th Anniversary',
#  'Botanical Vines',
#  'Tan Cover / Green Notebook',
#  '6 Pockets,blue,11x21in',
#  'Farm Buddies',
#  'Skull B Painting',
#  'Tobacco & Patchouli',
#  'Desert Twilight 9',
#  '36", Black',
#  'Baby Light Blue',
#  'Za-7054',
#  'Navy Vinyl',
#  'Rhodesian Ridgeback',
#  'Mountain Birch (Logs Only)',
#  'TN12 2016 CW+MCC-2+2X3400',
#  'Dark Red 4pcs',
#  'Aqua/ Chrome',
#  'Brushed Nickel B20',
#  'A-Dark',
#  'White Table Black Legs',
#  'Florida',
#  'Amehtyst',
#  '2 Pc Metallic Silver',
#  'Quatrefoil-spring Green',
#  'Black Leopard',
#  '27 LED -12 Pack',
#  'Vanilla Cream',
#  'Sand/Bronze',
#  'Green Laser',
#  'Brushed Nickel with Overflow/Detachable Basket',
#  'Zoomable',
#  'Bowl With Salt Ball',
#  'Pink Passion',
#  'Rose-green',
#  'Canvas White',
#  'Hippie Love',
#  'Fleur Blue',
#  'B-driftwood',
#  'TX11 FLASHLIGHT',
#  'Multi/ Black',
#  'Recipe Box',
#  'MIXING BOWL SET',
#  'Rest - Mint Green',
#  'Green/Red/Orange/Black',
#  '2 Skull Shot Glasses',
#  '3 pcs Green Bags',
#  'Relaxing Eucalyptus',
#  '0.625" Bamboo',
#  'Black 5mm, 2pk',
#  'Vizsla',
#  'Eggplant Greek Key',
#  'CAPITAL | Yellow | Qty: 1',
#  'YSH005C',
#  'Gold Fish',
#  'Tulip&Daisy 6 Cavity',
#  'Wintergreen',
#  'Crisp Summer Breeze',
#  'D2',
#  'Geranium',
#  'Driftwood Gray',
#  'Gray, Gray, Gray',
#  'Chrome Skull',
#  'Pomegranate Red',
#  'W/Edge Green',
#  'Yellow Leaves',
#  'Trendy Plastic Blue Black',
#  'Yellow Strip Light',
#  'Sudbury Bronze / Energy Star',
#  '#277',
#  'Peony flower',
#  'Glass/Clear',
#  'Pinkie Pie & Princess Twilight Sparkle',
#  'Black-4 pcs',
#  'Tide White',
#  'Parchment Chrome',
#  'Baby\'s First Year 13-Opening - 1" Border',
#  'Beige-N',
#  'Purple Orchid',
#  'Antique-pewter',
#  'Matt White - Square',
#  'Microfiber Suede Mocha Brown',
#  'Penguin - Merry',
#  'SUNK-IN',
#  'Bronze/Black',
#  'Beware of Dog & Cat is Shady',
#  'Box With Elephant & Carvings',
#  'Maze',
#  'Best Seller',
#  'Cherry/Maple/Walnut',
#  'IIUU25',
#  'Grey & Navy',
#  'Virtu Black',
#  'Holes Distance: 12-3/5"',
#  'White With Blue Stripes',
#  'Gothic Red',
#  '16" X 24" Grey',
#  'R15',
#  'Antique Cherry/White Mist',
#  'Chinese Zodiac',
#  'Teal Dolphins',
#  'Victory Garden',
#  'Blue Ink Wave',
#  'Copper Antiqued',
#  'Birdies',
#  'M10 Red',
#  'Owl-M1',
#  'Grey Driftwood',
#  'Daylight (6500k)',
#  '1 PCS-used',
#  'Antique Brass Double Bars',
#  'Perennial',
#  'soup spoons',
#  'Pattern 25',
#  'Red/Yellow/Green "Stainless Tool"',
#  'Red Beetles',
#  'Bazinga!',
#  'Navy Anchor Plaid',
#  'Coral Pink',
#  'Red & White Check',
#  'Crystal Skirt Hangers - 12 Pack',
#  "No Peein'",
#  '19pcs set',
#  'Purple Glitter',
#  'Dusk Heather',
#  'Clear Anti fog',
#  'Dolphin Decorative Window Film',
#  'Peyote 10',
#  'Mickey & His Pals',
#  'Paisley Print',
#  'Twilight Purple',
#  '#White',
#  'Star Wars Vader',
#  '24w-3000k',
#  'Magnolia Wood',
#  'HQJ-17',
#  'Toucan',
#  '11 Pcs Regular (Waist 23" to 35")',
#  'Monaco Blue',
#  'Wide Slat Dark Brown',
#  'Blue, Amber',
#  'Purple and Orange',
#  'Summer Hill',
#  'John Cena 1',
#  'Abstract Brown',
#  'White (3-pack)',
#  'Sf10 - Brown',
#  'Authentic',
#  'Mockingbird',
#  'Hamilton Plaid/Slate Black',
#  'Style-6',
#  'Morning Rooster',
#  'Stainless Steel/White',
#  'White/Grey/Green/Light Yellow',
#  'Tye Dye',
#  '32.8ft Wifi Light Strip Kit',
#  '5-Pack Milti',
#  'C-3PO',
#  'Classic Pink',
#  '23247778 4-pack',
#  'Titanium Tool + Clear',
#  "In Dog Beers, I've Only Had One",
#  'Desert Flower',
#  'GOLD PEACOCK',
#  'Multi17',
#  'SAPPHIRE',
#  'Dbs-12 : 1.96 Feet X 9.84 Feet',
#  'Brushed Nickel-8inch',
#  '#Green Olive',
#  '246',
#  'Compact Herb',
#  'Might Be Wine',
#  '62.5 In.',
#  'Blue(hy)',
#  'Rasta Peace',
#  'Cc837',
#  'Silver-pink-fuchsia',
#  '17.25',
#  'Sheer/Pink',
#  'Natural Leaf',
#  'Angel With Cloak',
#  'X-shape Connector(10pack)',
#  '44lb-silver',
#  'White Gray Stone',
#  'Pink Medley',
#  'Dark Brown-beige',
#  '2PC-7W',
#  'Metro Gray',
#  'B-028',
#  'All Clear - Removable Insert',
#  'Snow-Silver Gray',
#  '6pcs White',
#  '3 Pair-Pink Frame-Clear Lense',
#  '12 oz State Hammered Goblet',
#  'JI45',
#  'Purple She Said Yes',
#  'Red Sit',
#  '16 Inches Wide',
#  'Ice Rustic',
#  'Warm White--',
#  'Brushed Aluminum',
#  'Ocean Ripple',
#  'Rims, Clear/Gold',
#  'oil rubbed bronze',
#  'Classical Ornament',
#  'Mickey Classic',
#  'Seven Dwarfs Group',
#  'Brovada5pc Set',
#  'Navy/ Beige',
#  '13pcs for Roomba 600',
#  'Wzs-6',
#  'Olive Drab/Cinnamon Brown',
#  'Cube Frosted',
#  'COFFEE TOGETHER',
#  'Black Frame/Gray Anti-Fog Lens with Black Cord',
#  'Black/ Brown',
#  'Rusty Red',
#  'White (Ultra-Fresh)',
#  'Sea Mist',
#  'Upschitz Creek',
#  'A-Lily',
#  'Matte Black Frame',
#  '12pcs Cool White',
#  'Navaho Wind/Pine',
#  'Ivory, Stainess Steel',
#  'Summer White',
#  'Super Steel',
#  'Solid Aqua',
#  'Polyester Button Grey',
#  'E09',
#  'Yellow/Gray',
#  'Powder Room',
#  'Polished Chrome/White',
#  'Color Whale',
#  '8"',
#  'Red Burlap',
#  'Red/Cream',
#  '6 Piece Set - Round, Metallic/Clear',
#  'St. John Paul Ii',
#  'Navy/Sand',
#  'Blue Cap Blue Floral',
#  'Great Pyrenees Named Wilson Tote Bag',
#  'Clear_green',
#  'CC-1',
#  'Pine Birds',
#  'Grey-#1',
#  'Whiskey Wood',
#  '3pcs ball tips',
#  'Stainless Steel, Black',
#  'Connector-wire-connector(10pack)',
#  'coasters',
#  'Sex lady',
#  '3 packs Mineral Balls',
#  'Candy Buttons',
#  'Love Birds',
#  'Windsor Oak',
#  'Wire Brush',
#  'T-shape Connector(10pack)',
#  'Allure Granite (Privacy & Light Filtering)',
#  'Basketball',
#  'Ivory/Orange',
#  'Green Dot',
#  'Steel Gray',
#  'Cc850',
#  'Tile Grey',
#  '3-Piece Ceramic Dark Grey',
#  'stainless./red',
#  'Tissue Box Cover',
#  'gold34',
#  'French Bread',
#  'Nag Champa',
#  'Bluejean',
#  'Magnet Bottle Opener',
#  'Silver (PPL-06S Mini Slider with Ball Head)',
#  'Baby Powder',
#  'Out of This World - Glow in The Dark!',
#  'Black Wood',
#  'Crystal Clear Frame, Silver Mirror Lens',
#  'Might Be Whiskey',
#  'Red Skull Camo',
#  '20150603A2-20150603002',
#  'Queen Trellis Teal',
#  'Clear/Blue',
#  'Chocolate Brown Beige and Mocha',
#  'Blue - Orange',
#  'Diamond Yellow',
#  'Antique Maple',
#  'Canvas Wall Art 19',
#  'Oak Veneer Base',
#  'Indigo/Navy',
#  'Love',
#  'Green Brown',
#  'Tahfta Grey 42" x 25"',
#  'Gray Multi',
#  'Barrel',
#  'Cinder Gray',
#  'BMW Gray',
#  'Red & Green',
#  'G-f Dark Grey',
#  'two ring',
#  'Multicolor-10 oz',
#  'Satin Brass Hinges',
#  'Two Orange',
#  'Red Mountain Scene',
#  'Curved Steel',
#  'Brown Longhorn',
#  'Gradient Ramp Pink',
#  'Hdsw001-pink',
#  'White Marble',
#  'No8',
#  'XT2C',
#  'Pique-nique Vichy',
#  'Coral / Light Grey / White',
#  'Lifestyle Blue',
#  'White Rectangular 2',
#  'Pink Santini',
#  'Blue, Black, White',
#  'Brushed Oak',
#  '16PC DINNERWARE SET',
#  '40 oz',
#  'Almond (Ivory)',
#  'Green and Brushed Nickel',
#  'Style12',
#  'Beige&brown',
#  'Fractal Fun',
#  'Mode a Black',
#  '3900 headlamp',
#  'Silver Sage',
#  'Guacamole',
#  'Satin - Large',
#  '40th Bday',
#  'Sweet Pea & Vanilla',
#  'Farmhouse Brown',
#  'Brown Dome',
#  '7w-cool 6000k-1pack',
#  'Purple Lilac',
#  'Natural/Coffee Bean',
#  'Style02',
#  'Chinese Flower',
#  'Rare Cats / Sphinx-san / Ramses the Great/Ver 2',
#  'Sheer/Vapor',
#  'Blue&Purple',
#  'Ultimate Girl, Pink',
#  'Black Opaque',
#  'Warm Silver',
#  'C-pack of 24 Timer Candle',
#  'Champangne',
#  'Grey-002',
#  'Pretzel - Hoppy',
#  'Provence Crackle',
#  'Recycled Wood',
#  'GR33. Gold',
#  'Yellow 12segs B',
#  'black+blue',
#  'France',
#  'Stone Blue/Beige',
#  'Orange/Multicolor',
#  'Sweet Hearts',
#  'Mandarin Sage',
#  '0z-1vf5-ydxo',
#  'White-Opaque',
#  'GR29. Silver',
#  'Wall detector',
#  'WHISKED OFF',
#  'Deluxe Combo',
#  'Warm White LED Strip',
#  'Black-5 Branches',
#  'Black-s1',
#  'Strip+music Remote+power',
#  'Orange / Clear',
#  'Slate with Natural Core',
#  'Sun Kissed',
#  'various',
#  'ZJZ-793',
#  'Vertical J Red',
#  'weizhi',
#  'I Love My Chihuahua',
#  'Warm White (2700k)',
#  'NUMBER',
#  'Eiffel Tower and Postmark',
#  'Manger Magi Dual',
#  'Create a Cart',
#  'Clear Butter Dish',
#  'Purple Passion',
#  'Soft White - 23-watt',
#  'brushed Nickel',
#  'Heritage Blue Cc7',
#  'Metallic Gray',
#  'Grey Groove',
#  'Cobalt-blue',
#  'Black Gloss/Black Matte',
#  '2 Pack 18" X 18"',
#  "Cat's Eye",
#  'Blue Grey',
#  'Parsly & Peppers',
#  '10.5" Chef Bowl',
#  'Fabric Folding Baskets/Cherry',
#  'Neutral White- Silver Wire',
#  'Cousteau',
#  'orange Wood',
#  'Pink Twin Comforter',
#  '10 in 1 Plier',
#  'Letter G',
#  '3.black-holder',
#  'Pomegranate & Spruce',
#  'whisk set',
#  'Scratch Resist',
#  'TCG400',
#  '9x 3ml',
#  'Circle Pattern',
#  'Burgundy Twill',
#  'Brushed Steel With Bling',
#  'Double Side Mirror',
#  'Orange 2',
#  'Double Dash',
#  'Black and White Flower',
#  'GW22004',
#  '3pcs-warm White',
#  'Norse',
#  'Black Bird Cage',
#  'Style 40',
#  'Perforated / Cream',
#  'Solid Conical',
#  'Violet & Lilac Chevron',
#  'Red/Silver-6',
#  '6 Set-Coaster-Multi-color',
#  'Blue/Beige',
#  'CHESE DEGREES',
#  'Southwest Tribal Woven Tan w/ Brown',
#  'Medium Green Teal 10-Piece',
#  'Me-bzx-121',
#  'Medium Blue',
#  'White With Red Cutouts',
#  'Alaskan Midnight Black',
#  '19*23 Inch-Hot Pink',
#  'Sofa Cover, Chair, 23"x74"',
#  'C. Grey',
#  'No circles',
#  '4pcs without comforter-27',
#  'White/Gray',
#  '8 Yellow Green',
#  'Bling Bling 01',
#  'Brown Tri-color',
#  'Silver Beige',
#  'Marines Logo',
#  'Cinnabar Orange',
#  '28"X15" Dolphins',
#  'Gold Flower',
#  'Peyote 8',
#  'Pueblo Pattern, Tan/Blue',
#  'Mightblue',
#  '15ATR GFCI A/T 1PK',
#  '3/8 in. x 50 Feet',
#  'Antique Rose Gold',
#  'Gray and Purple',
#  'The Pink Peach Tree',
#  'Tamiya',
#  'High Gloss',
#  'Ti BLACK',
#  'Green #3 Reversible',
#  '600LED 3000k 164Lumen/ft',
#  'Polished Horn',
#  'Butterfly Garden - Red',
#  'Kitchen Rules',
#  'Sesame',
#  '91750880',
#  'T Type,Dual Way',
#  'Cool White Timer',
#  'Day at the Pond',
#  '(20x28) Black Solid Wood Framed Poster',
#  'TN40S CW',
#  'Banksy Panda With Handguns',
#  'Brushed Bronze Finish',
#  '5W',
#  '3',
#  'Light Grey/Purple',
#  'Light Woodgrain',
#  'CW/CCW',
#  'Earth Grey',
#  'Black #A',
#  'Smokey Quartz',
#  '2 pack 3-pole',
#  'Unify-5000K Non-dimmable',
#  'Wine Silver',
#  'Renu Brown',
#  'Mahogany Frame',
#  '10039',
#  'Ochre',
#  'Yellow 01',
#  '4 Green (Gg)',
#  'American Cherry',
#  'Walnut Brown',
#  '02pack',
#  'Barrel Shaped 1.3 Gal',
#  'Cream &amp; Turquoise',
#  'Champagne*',
#  '6 Pack (Warm Light)',
#  'P-Pillow342',
#  'Decorative Flowers',
#  'Summer Turquoise',
#  'Contour',
#  'Holiday Red',
#  'Small Christmas Tree',
#  'Medium 12 in - Basic Design - Mother of Pearl',
#  'Blue-dot',
#  'Water Green',
#  'Pumpkin Light',
#  'Bright White (3000k)',
#  'Blue/ Silver',
#  'Cc1010',
#  'Red Green Gold/Jacquard',
#  'Epoxy Chrome',
#  'Black/Clear',
#  'Blue Bird, Set of 1',
#  'Blue - Puppy Dog',
#  'Green - White',
#  '40ft - Green',
#  'Rustic Rectangle',
#  'Fleurs Des Indes Multi Color',
#  'Rainwater',
#  'Black With Chrome',
#  'Dimmable E14 3W',
#  'Blue Recycle',
#  'Happy Birthday-lavender-white',
#  'Gold - Large',
#  'Aegean Coral 45',
#  'Fashion Blue',
#  'Gem Blue',
#  '#2 Most Necessary',
#  'Perforated / Bronze',
#  'Pillow Ef#15',
#  'Ivory And Beige',
#  'Safari Ocean',
#  '20packs Black',
#  '002',
#  'UF-KCH01',
#  'Coral Fleece-grey',
#  'Antler Love',
#  'Flame/Marigold/Petal',
#  'SAFETY RED (bright) - $44.97',
#  'POLOR PICKS',
#  'Merry Christmas Ornament',
#  'Compass Ink',
#  'Caribean',
#  'Black/ Red',
#  'Dark Brown 2pcs',
#  "Baby's First Christmas",
#  'Football + Thanks + Congrats Pack of Four',
#  'Red/Green/Blue',
#  'Craftsman Oak- White',
#  'Upgraded Version',
#  'Black-(white Lighting-plug Wired)',
#  'Slub Twilight Teal',
#  'Endless Summer',
#  'Gloss Lobster Red',
#  '1 pcs tester only',
#  'White, Silver Gray',
#  'Helm Steering Wheel Blue White',
#  'Star Wars Darth Vader',
#  'Style #1004-10',
#  '1200 - Light Blue',
#  'Black, Mustard, Wine',
#  'Ruby',
#  'Cobblestone',
#  'Brushed Nickel Drain',
#  'Lightning Skull',
#  'Pink navy',
#  'BlackCoated',
#  'Pale Green, Cream, Beige, Tan, Brown',
#  'Candelabra 6000k',
#  'Charming Shell',
#  'Chocolate Stripe/Chocolate',
#  'Gold Circles',
#  'Twinkle',
#  '03-Multi',
#  'Drak Blue',
#  'FROG',
#  '2W LED-6 Pack',
#  'Colorful LB-126',
#  'Chocolate/Aritichoke',
#  'Courageous',
#  'Multi25',
#  'Multi 50',
#  'Multi Bold',
#  'Sage Olive Green',
#  'D6 Style',
#  'Natural Green',
#  '56896295',
#  'Rustic Ivory',
#  'Sherpa Quilted Throw - Burgundy',
#  'Corkscrews',
#  'Brushed Nickel-043',
#  'Ball',
#  'SAIL',
#  'Chrome-16378',
#  'Graham Cracker',
#  'Top Hat Tree Topper',
#  'Beige, Brown',
#  'Sport - Hot Pink/Blossom',
#  'Khaki and Black Stripe',
#  'as shown',
#  'Trinell 2-drawer',
#  'Blood Orange',
#  'Gloss Pure White',
#  'Coyoacan',
#  'Silver Metal',
#  'Teddy Bear',
#  'Gun Red',
#  'Finally Someone With Balls',
#  'Holiday Pups',
#  'Urban Red',
#  'Sage-green',
#  'JZVC013SJZ',
#  'Bff Frappe',
#  '6" 12 Panel Kit (6000k)',
#  'SD06L',
#  '128',
#  '24-105mm Lens Cup With Transparent Lid',
#  'Powell Blue',
#  'lattice daisy lace',
#  '2.3 Qt - Mint',
#  'Thunder Tan & Offwhite',
#  'EAGLE EYES | GREEN | PLASMA JET, MIG, TIG, ARC/AIR',
#  '+1.25 New Style',
#  'Brilliant Steel',
#  '386',
#  'Grey and Green',
#  'Red, Black, White, Gray, White',
#  'Feline Family',
#  'Artwork02',
#  'Grater',
#  'Orange-black',
#  'Chocolate Leaf',
#  'Tranquility',
#  'Castle Flower',
#  'Warm Cocoa',
#  'cake Cup',
#  'Flourescent Lime',
#  'Pattern 12',
#  '05#',
#  'Southern Pacific Train 2472',
#  'White with Pink, Purple, Green',
#  'San Francisco - 2',
#  'White/Violet',
#  'Canterberry Magenta',
#  '111',
#  'Stripes Series Green',
#  '1pc Light Pink',
#  'Granite Navy and Taupe',
#  '2 Pack,rechargeable',
#  'Blue',
#  '8 Pack',
#  'Cat and Mouse',
#  'Royal Blue/Blue/Green/Orange/Red/Turquoise/White',
#  'Fibreglass',
#  'Lemon Drop',
#  'Au Natural',
#  'D69',
#  'Warm White 2700k',
#  '#810 Small Pink',
#  'Duo Heart',
#  'Carnaby Street Kensington',
#  'Wall Mounted',
#  'BananaHanger',
#  'Texas & Texas',
#  '04',
#  'Color 3 Beige',
#  "Zoom-Zoom Z's",
#  'Clear 6"',
#  'Coral Mint Peach Gold',
#  'Vintage Red',
#  'Lace Set 2',
#  'Florida State Seminoles',
#  'Pooh Bear Woods',
#  'Update-Black',
#  'Burled Wood',
#  'Nylon - Bead Blast',
#  '70mm',
#  'Purple Logo',
#  '13 Gauge Polyester Shell, Latex Dip',
#  'Tranqillo',
#  'Beachy Stripe Pink',
#  'Robin',
#  'Hanukkah',
#  'Yellow 45 in 1',
#  'Metallic Blue',
#  'Mulberry Embossed',
#  'Schedule',
#  'Lotion Black',
#  'T0429-s',
#  'Sapphire/Emerald',
#  'Shiny Black',
#  '10Pcs HSS Router Burr Sets12-3mm Shank',
#  'Beechwood Finish',
#  'Blue Mosaic Square',
#  'Clear Cover',
#  'Lime Placemats',
#  'Lolli - Large double heart',
#  'Wildberry Purple',
#  'Orange/Pumpkin Spice',
#  'Indigo blue',
#  'Orange / Dark Grey',
#  'Flower2',
#  'Keep Calm and Carry on',
#  'GREEN COLOR 15 LEDs 6 FEET 2 SETs',
#  'Black and White Forest',
#  '22mm - Black',
#  'Rectangular Prep Board',
#  'A+royal Blue',
#  'Cherry Embossed',
#  'Coffee Style-2',
#  'Manual Advanced 2000 Count',
#  'Peaceful Yard',
#  'Audacious Plum',
#  'Daughter 2',
#  'chrome-6089',
#  'White with Clear Lid',
#  'Cheap Shotz',
#  'White-Silver (2 to 2)',
#  'Cliff Walk at Pourville',
#  'Rose Set',
#  'Guns Welcome',
#  'Mint/Sea Foam',
#  'Ocean Waters',
#  'Hummingbird All (Set of 2)',
#  'Matt Black Shwoer Panel',
#  'T6 Black',
#  'Red Set/4',
#  'Amber+Metal+Tea',
#  'G.rainbow',
#  'Niall 4',
#  'Mediterranean Patina',
#  'Blue / Bone',
#  'Polished Chrome-8',
#  '20Ft Pure White',
#  'Designer Texture Decorative Window Film',
#  'Black Matt with black frame B1 31080BFG',
#  '3d Cube',
#  'American Eagle Biker',
#  'H) Orange (100pcs)',
#  'Harper Cocoa / Wizard Caviar',
#  'Double Denim Blue',
#  'Red w/White LED',
#  '32oz Black',
#  'True North',
#  'Silver With Black',
#  'Power Blue',
#  'Silvery Moon',
#  'WH-6',
#  'YLLB-01',
#  'Cappuccino',
#  'Shiny Black/Clear',
#  'Marriage',
#  'FLB-007',
#  'CEREAL KILLER WEAPON OF CHOICE',
#  'Lp328',
#  'Orange/ yellow',
#  'Spice/Dark Gold',
#  'Perfect Pink',
#  'Red&orange',
#  'FLB-029',
#  'Palm Trees on the Tropical Beach - 03',
#  'White / Silver Rim',
#  '#T2',
#  'Bluebell Forest',
#  'Blue4',
#  'Gold 20',
#  'Red 91 "X20 "',
#  'Queen Bee',
#  'White on Moss Green',
#  'Light Brown Mahogany',
#  'Pgs406 : 2.00ft X 6.56ft',
#  'Beige & Hooks',
#  'Barbie Pink',
#  '2 PCS',
#  'Light Blue/Royal Blue',
#  '8w White',
#  'Brushed Nickel 19',
#  'Ginger',
#  'White with Black Lid',
#  'Gold 100',
#  'White Wind 20',
#  'Barleycron Sterling Silver',
#  'Pink Flower With Pink Pockets',
#  'WHITE & GREEN',
#  'Chololate',
#  '3 Pack - Natural',
#  'Del Sol',
#  'Baking Mat',
#  'Color#108',
#  'Green Metal Shades',
#  'White Stipple',
#  'Diamond Nautical Blue',
#  'Statue 6',
#  'Black+White (Upgrade Version)',
#  'Usb Powered',
#  'Green-cream',
#  '12 Pack - Assorted Colors',
#  'CHOCOLATE',
#  'Lilac Garden',
#  'Leaves of Lain',
#  'Blue, green&red',
#  '4pcs Mix Color',
#  'Desk Lamp',
#  'Frg43-w',
#  'Wood+ Lcd',
#  'Yellow Checkered',
#  'T30-128-110v',
#  '91 Dark Wax',
#  'Leopard Plaid',
#  'wine opener',
#  'Christmas Present',
#  '004 - Life is Now',
#  'Sleep Dogs',
#  'Water Flowers Scented',
#  'Variety Set of 3',
#  'Dark Indigo',
#  'Satin Ivory Silk',
#  'Black/White/Grey',
#  'The Boot Rack With 6 White Hangers',
#  'Serene Rose',
#  'Cranberry Glass Plug-in Warmer',
#  'Gloss Lagoon',
#  'Dahlia Yellow',
#  '.825" Rich Gold',
#  'Chic Pink',
#  '12 Cavity Flowers',
#  'Sunrise',
#  'Lattice Nautical Blue',
#  'Cranberry Red & Cream',
#  'Big Dots',
#  '2016',
#  'Two Pair Hook Gray',
#  'Outdoor Camo',
#  'Yellow 13" Black Frame/Black Hands',
#  'OWL',
#  'Pure red/ set of 10 (55ML)',
#  'Blooming',
#  'Beware Of Dogs Keep Gate Closed',
#  'Stripe Coffee/Grey',
#  'A-light Linen',
#  'Fabulous',
#  'Warm White Led Bulb',
#  'IRXL220',
#  'English Teacher Zone',
#  '300 Feet',
#  'Brown Coffee',
#  '#C',
#  'Rose-6',
#  'Hong Kong Time',
#  'Violas',
#  'Roseo Lotus',
#  'Sparkle Purple',
#  'Lime Green Throw Pillow Shams',
#  'Blue X 4pcs',
#  'Black Handle + Lid',
#  'Sage Green Leaves',
#  'Burgundy Owl and Moon',
#  'BLACK AND PINK',
#  'Napkin Holder',
#  'Holiday Pack 1',
#  '3 Pockets,blue,11.8x25.2in',
#  '15 Inch',
#  'Essential Opaque Off-white',
#  'Chalkboard Caddywith Wood Tray',
#  'White / Cream',
#  'Solemn Lime',
#  'Without Fuel Gauge',
#  'Shadow Green',
#  '6-piece Set_brown Sugar',
#  'Blue Mirror 1 Pair',
#  'For 9 Lipstick + 2 Compartment',
#  'Blue for Kids',
#  'White Pcb Ip30',
#  'Artwork - 23',
#  'Chocolate Diamond',
#  'Bud Light Classic',
#  'Clear/Frosted',
#  'Rose and Lavender Set',
#  'Bubble Stirpes',
#  'Black/Red/Silver',
#  'St131',
#  '21pc Acrylic Silver Stars Mirror',
#  'Black``',
#  'Pink-purple',
#  'Black 5/8 Oz',
#  'The Angel & Pink',
#  'Brown/Grey',
#  'Dali Natural',
#  'Mountain Snow (Thermal)',
#  'Skulls With Led Eyes Wreath',
#  'Tmnt- Michelangelo',
#  '5" Ivory',
#  'set of 4 snowflake plunger',
#  'Terra Cotta',
#  'Live Oak (LP) (includes gas connection kit)',
#  'Fluorite Pack of 3(1.5"-2")',
#  '24" X 35" Green Stripes',
#  'Black & White Zig-zag',
#  'Medallion Blue',
#  'Black Turquoise',
#  'white4',
#  '80 Grit Set',
#  'Rust-Orange',
#  'Groot',
#  'Owl Shape',
#  'Bouy 3',
#  'light Beige',
#  'Palace',
#  'Flower Pattern',
#  'Whiteblack',
#  'Dr. Seuss',
#  '09. Wheat Field With Cypresses',
#  'NO Adapter',
#  'Lavender Topaz',
#  'Aqua Elephant',
#  '48 156 864 Frames 3-in-Set',
#  'Navy - Red',
#  'Teal,',
#  'Skyblue stripe',
#  'Single Peacock Feather',
#  'H:16.25" Open:6.75"',
#  'City Skyline Charcoal',
#  ...}

# %%
attributes["Colour:"]
# Out:
# {'Silicone Stretch Lids'}

# %%
attributes["Format:"]
# Out:
# {'Accessory',
#  'Audio CD',
#  'Baby Product',
#  'CD-ROM',
#  'Computer Game',
#  'DVD',
#  'Electronics',
#  'Hardcover',
#  'Health and Beauty',
#  'Home',
#  'Housewares',
#  'Kitchen',
#  'MP3 Music',
#  'Misc.',
#  'Misc. Supplies',
#  'Office Product',
#  'Paperback',
#  'Software Download',
#  'Spiral-bound',
#  'Sports',
#  'Target',
#  'Tools & Hardware',
#  'Tools & Home Improvement',
#  'Toy',
#  'Unknown Binding',
#  'Vinyl',
#  'Wireless Phone Accessory'}

# %%
import csv
with open('../data/attributes.csv', 'w', newline='\n') as csvfile:
    for attr, val_set in attributes.items():
        for val in val_set:
            csvfile.write(val)
            csvfile.write('\n')
