# %%
# !pip install wordfreq
# Out:
# Requirement already satisfied: wordfreq in c:\users\andre\miniconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: ftfy>=6.1 in c:\users\andre\miniconda3\lib\site-packages (from wordfreq) (6.1.1)
# Requirement already satisfied: msgpack>=1.0 in c:\users\andre\miniconda3\lib\site-packages (from wordfreq) (1.0.4)
# Requirement already satisfied: langcodes>=3.0 in c:\users\andre\miniconda3\lib\site-packages (from wordfreq) (3.3.0)
# Requirement already satisfied: regex>=2020.04.04 in c:\users\andre\miniconda3\lib\site-packages (from wordfreq) (2022.1.18)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\andre\miniconda3\lib\site-packages (from ftfy>=6.1->wordfreq) (0.2.5)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)

# %%
import gensim.downloader
import spacy
import pandas as pd
import ast
from wordfreq import word_frequency

# !spacy download en_core_web_sm
nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\users\andre\miniconda3\lib\site-packages (from en-core-web-sm==3.2.0) (3.2.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.9.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: jinja2 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.13)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.22.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.27.1)
# Requirement already satisfied: setuptools in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (60.5.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\andre\miniconda3\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\andre\miniconda3\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\andre\miniconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\andre\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\andre\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\andre\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\andre\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\andre\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\andre\miniconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\andre\miniconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\andre\miniconda3\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\andre\miniconda3\lib\site-packages)

# %%
from scipy.spatial import distance

# %%
def cosine_similarity(first_word, second_word):
    return 1 - distance.cosine(first_word, second_word)

# %%
data = pd.read_csv('../data/spacy_tokenized.csv')[["Tokens", "Tags"]]

# %%
with open('dpt_store_centroids.txt') as f:
    dpt_store_centroids = f.read()
        
# reconstructing the data as a dictionary
list_taxon_dict = ast.literal_eval(dpt_store_centroids)

taxon_dict = {}

for k, v in list_taxon_dict.items():
    taxon_dict[k] = np.array(v)

# %%
def get_sentences(df, with_iob=False):
    
    current_sent = ""
    
    all_sents = []
    
    for i, row in df.reset_index().iterrows():
        if type(row.Tags) == str:
            if not with_iob:
                current_sent = current_sent + row.Tokens + " "
            else:
                current_sent = current_sent + row.Tokens + "-" + row.Tags + " "
        else:
            all_sents.append(current_sent[:-1])
            current_sent = ""
            
    return all_sents

# %%
all_sents = get_sentences(data)
all_sents_iob = get_sentences(data, True)

# %%
# def get_highest_similarity(sent, i, verbose=False):
#     """
#     Returns the cosine similarity score between the word at index i and the composite vector representing the taxon
#     to which the word is most similar.
#     If verbose, also prints the name of the taxon to ensure that the output of the function is sensible.
#     """
    
#     highest_similarity = 0
#     sent = nlp(sent)
#     word = sent[i]
#     if word.lemma_ in glove_vectors:
#         if word.pos_ in {"PROPN", "NOUN", "ADJ"}:
#             for k, v in taxon_dict.items():
#                 similarity = cosine_similarity(glove_vectors[word.lemma_], v)
#                 if similarity > highest_similarity:
#                     highest_similarity = similarity
#                     taxon = k
#                 if verbose:
#                     print(k, ":", similarity)
#     elif word.pos_ == "PROPN":
#         return None
                        
#     if verbose:
#         print("\nTaxon with highest similarity :", taxon)
                
#     return highest_similarity

# %%
# def get_frequency(sent, i):
#     """
#     Returns the frequency of the word at index i, multiplied by 1000 for readability.
#     """
    
#     sent = nlp(sent)
#     word = sent[i]
    
#     return word_frequency(word.lemma_, "en") * 1000

# %%
def get_sim_freq(sent, i, taxon_dict, verbose=False):
    """
    Returns the ratio between the similarity between the word and the taxon to which it is most similar and the word frequency.
    This is to account for the fact that more frequent words tend to be assigned higher similarity scores to other words
    even when not intuitively semantically similar.
    The ratio is divided by 10 for readability.
    """
    
    highest_similarity = 0
    sent = nlp(sent)
    word = sent[i]
    if word.lemma_ in glove_vectors:
        if word.pos_ in {"PROPN", "NOUN", "ADJ"}:
            for k, v in taxon_dict.items():
                similarity = cosine_similarity(glove_vectors[word.lemma_], v)
                if similarity > highest_similarity:
                    highest_similarity = similarity
                    taxon = k
                if verbose:
                    print(k, ":", similarity)
                    
    elif word.pos_ == "PROPN":
        highest_similarity = 1
    
    if verbose:
        print("\nTaxon with highest similarity :", taxon)

    if not highest_similarity:
        highest_similarity = 0
        
    frequency = word_frequency(word.lemma_, "en") * 1000
    
    if frequency != 0 and highest_similarity > 0:
        return highest_similarity / frequency / 10
    
    else:
        return 0

# %%
def sim_freq_2_ordinal(sim_freq):
    
    """
    Converts similarity-frequency ratio to an ordinal representation by representing it as a set of binary variables.
    This is because CRFsuite cannot use numerical features directly.
    """
    
    
    
    zero = sim_freq == 0
    one = sim_freq == 1
    tenth_half = sim_freq >= 0.1
    half_one = sim_freq >= 0.5
    one_three = sim_freq > 1
    three_five = sim_freq >= 3
    five_ten = sim_freq >= 5
    greater_than_ten = sim_freq >= 10
    
    return zero, one, tenth_half, half_one, one_three, three_five, five_ten, greater_than_ten

# %%
for sent in all_sents[:20]:
    sent = nlp(sent)
    for i in range(len(sent)):
        print(sent[i])
        print("similarity-frequency ratio", sim_freq_2_ordinal(get_sim_freq(sent, i, taxon_dict)))
        print()
    print("\n\n")
# Out:
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# am
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# black
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# gloss
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# 33
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# inch
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# fireclay
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# apron
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
# sink
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
#
#
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# pre
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# workout
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# pump
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# addict
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# instead
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# of
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# karbolyn
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# hydrate
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# with
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# one
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# is
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# better
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# need
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# 48
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# inch
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# glass
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# sliding
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# good
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# and
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# shower
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# pan
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# system
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# 500.99
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# or
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# less
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
#
#
#
# hello
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# ,
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# any
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# of
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# your
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# free
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# standing
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# stubs
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
# have
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# matte
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# white
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# finish
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# instead
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# of
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# glossy
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
# finish
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# '
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# m
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# 24
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# inch
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# white
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# mirror
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# that
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# is
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# freestanding
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# and
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# reasonably
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# priced
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# does
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# linen
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
# add
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# cotton
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# duet
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# cover
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# come
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# in
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# king
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# saw
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# it
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# in
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# store
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# but
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# n't
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# see
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# king
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# size
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# online
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# hi
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# there
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# '
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# m
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# to
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# buy
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# some
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# throw
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# blankets
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# your
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# website
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# states
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# that
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# underside
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
# of
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# double
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# wool
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# -
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# like
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# throw
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# is
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# very
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# soft
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# would
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# like
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# to
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# know
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# if
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# wool
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# -
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# like
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# top
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# side
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# is
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# soft
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# as
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# well
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# ,
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# or
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# if
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# it
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# is
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# scratch
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# have
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# hypersensitive
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# skin
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# and
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# need
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# blanket
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# that
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# will
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# not
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# irritated
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# me
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# thanks
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# long
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# sharp
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# jacket
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# dark
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# brown
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# why
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# ca
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# n't
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# find
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# it
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# hello
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# '
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# m
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# soft
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# open
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# face
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# cardinal
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# w
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# no
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# buttons
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# hi
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# you
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# carry
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# any
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# oval
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# stubs
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# in
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# matte
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# white
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# finish
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# or
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# not
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# too
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# much
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# of
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# gloss
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# know
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# they
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# make
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# solid
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# surface
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# but
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# higher
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# prices
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# thank
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# you
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# you
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# not
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# have
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# above
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# shower
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# walls
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# hi
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# '
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# m
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# considering
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# bathtub
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
# wives
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# panel
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# assume
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# it
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# does
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# n't
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# matter
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# which
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# way
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# bathtub
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
# is
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# facing
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# above
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# shower
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# base
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# not
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# so
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# much
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# $
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# lol
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# you
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# have
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# vanity
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# tops
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# or
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# wall
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# mount
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# sink
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# without
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# facet
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# holes
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# hi
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# !
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# !
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# '
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# m
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# 60
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# ''
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# wide
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# tub
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# but
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# soaked
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# type
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# that
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# s
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# deeper
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# than
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# regular
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# tub
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# you
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# have
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# this
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# type
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# ?
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# n't
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# see
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# anything
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# deep
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# enough
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# on
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# your
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# site
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
#
#
#
# ok
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# thanks
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# '
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# m
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# pure
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# white
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# above
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# bathtub
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
# ,
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# not
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# american
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# standard
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# or
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# any
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# off
# similarity-frequency ratio (False, False, False, False, False, False, False, False)
#
# whites
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# is
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# there
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# one
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# you
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# could
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# recommend
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# hi
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# ,
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# you
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# have
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# navy
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# mirror
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# size
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# 60x31
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# you
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# have
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# it
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# gold
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# and
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# black
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# but
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# n't
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# want
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# it
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# navy
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# hi
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# ,
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# am
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# a
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# floating
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# vanity
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# with
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# integrated
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# sink
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# &
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# counter
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# top
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# with
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# no
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# drill
# similarity-frequency ratio (False, False, True, True, True, True, False, False)
#
# holes
# similarity-frequency ratio (False, False, True, True, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# facet
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# as
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# our
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# facets
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# are
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# wall
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# mounted
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# you
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# sell
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
#
#
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# am
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# looking
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# for
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# soaked
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# tub
# similarity-frequency ratio (False, False, True, True, True, True, True, False)
#
# but
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# not
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# want
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# stand
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# alone
# similarity-frequency ratio (False, False, True, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# am
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# replacing
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# my
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# oval
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# jacuzzi
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
#
#
#
# where
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# is
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# the
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# mirror
# similarity-frequency ratio (False, False, True, True, True, False, False, False)
#
# on
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# here
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# .
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# i
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# do
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# n't
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# want
# similarity-frequency ratio (True, False, False, False, False, False, False, False)
#
# linen
# similarity-frequency ratio (False, False, True, True, True, True, True, True)
#
# cabinet
# similarity-frequency ratio (False, False, True, True, True, False, False, False)

# %%
sent = "looking for pre workout pump addict instead of karbolyn hydrate which one is better?"

# %%
all_sents[2] = "i need a 48 inch glass sliding goof and a shower pan system for 500.99 or less"

# %%
all_sents[5] = "does the linen and cotton duvet cover come in king?"

# %%
for word in nlp(sent):
    print(word, word.dep_, word.pos_, word.head)
# Out:
# i nsubj PRON need
# need ROOT VERB need
# a det DET glass
# 48 nummod NUM inch
# inch compound NOUN glass
# glass nsubj NOUN sliding
# sliding ccomp VERB need
# good acomp ADJ sliding
# and cc CCONJ sliding
# a det DET system
# shower compound NOUN pan
# pan compound NOUN system
# system conj NOUN sliding
# for prep ADP sliding
# 500.99 pobj NUM for
# or cc CCONJ 500.99
# less conj ADJ 500.99

# %%
def is_object(sent, i):
    """
    Returns whether the word at index i is an object, object modifier, or neither.
    These categories are more semantic than syntactic. For example, in a sentence such as "Does your X have Y attribute?",
    X and Y will be considered as object and object modifier, respectively, rather than subject and object.
    """
    
    sent = nlp(sent)
    
    if i > len(sent):
        return "not_object"
    
    if sent[i].dep_ == "pobj" and sent[i].head.text == "in" and sent[sent[i].head.i-1].lemma_ == "come":
        return "object_modifier"
    
    elif sent[i].dep_ in ["pobj", "dobj"] and sent[i].pos_ != "PRON":
        if sent[i].head.dep_ in ["ROOT", "xcomp", "ccomp"] or sent[i].head.dep_ == "conj" and sent[i].head.head.dep_ in ["ROOT", "xcomp", "ccomp"]:
            if sent[i].head.dep_ in ["ROOT", "xcomp", "ccomp"]:
                head_lemma = sent[i].head.lemma_
            elif sent[i].head.dep_ == "conj" and sent[i].head.head.dep_ in ["ROOT", "xcomp", "ccomp"]:
                head_lemma = sent[i].head.head.lemma_
            if head_lemma != "have":
                return "object"
            else:
                for word in sent:
                    if word.head.i == sent[i].head.i:
                        if word.text == "i":
                            return "not_object"
                        elif "subj" in word.dep_ and word.pos_ == "NOUN":
                            return "object_modifier"
                    elif word.head.text == "of" and word.head.head.text == "any" and  word.head.head.head.i == sent[i].head.i:
                        return "object_modifier"

            if word.head.pos_ == "ADP" and sent[word.head.i-1].dep_ in ["pobj", "dobj"]:
                return "object_modifier"

            return "object"
        
        elif sent[i].head.pos_ == "ADP" and sent[i].head.head.dep_ in ["ROOT", "xcomp", "ccomp"] and sent[i].head.head.lemma_ == "look":
            if sent[i].pos_ != "ADJ":
                return "object"
            else:
                return "object_modifier"
        
        elif is_object(sent, sent[i].head.i-1) in ["object", "object_modifier"]:
            return "object_modifier"
        
        elif sent[i].head.text == "of" and sent[i].head.head.text == "any" and sent[i].head.head.dep_ == "nsubj":
            return "object"
        
        elif sent[i].head.text == "than" and sent[i].head.head.dep_ == "acomp":
            if is_object(sent, sent[i].head.head.head.i) == "object":
                return "object"
            elif is_object(sent, sent[i].head.head.head.head.i) == "object":
                return "object"
        
        else:
            return "not_object"
        
    elif sent[i].dep_ == "punct" and sent[i].head.dep_ == "nummod":
        return "object_modifier"

    elif "mod" in sent[i].dep_:
        if is_object(sent, i+1) in ["object", "object_modifier"]:
            return "object_modifier"
        else:
            return "not_object"
        
    elif sent[i].dep_ == "compound":
        if is_object(sent, i+1) in ["object", "object_modifier"]:
            return "object_modifier"
#             if sent[i].pos_ == "ADJ":
#                 return "object_modifier"
#             elif i > 0 and sent[i-1].text.isnumeric():
#                 return "object_modifier"
#             elif sent[i].head.head.pos_ == "ADP" and is_object(sent, sent[i].head.head.i-1) in ["object", "object_modifier"]:
#                 return "object_modifier"
#             else:
#                 return "object"
        else:
            return "not_object"

    elif sent[i].dep_ in ["conj", "appos"] and (sent[i].pos_ != "VERB" or sent[i].tag_ in ["VBG", "VBN"]):
        return is_object(sent, sent[i].head.i)
    
    elif sent[i].dep_ == "relcl" and (sent[i].pos_ != "VERB" or sent[i].tag_ in ["VBG", "VBN"]):
        if is_object(sent, sent[i].head.i) in ["object_modifier", "object"]:
            return "object_modifier"
        else:
            return "not_object"
    
    elif "subj" in sent[i].dep_ and sent[i].pos_ == "NOUN" and sent[i].head.lemma_ in ["have", "come", "be"]:
        return "object"
    
    elif sent[i].dep_ == "acomp":
        return "object_modifier"

    else:
        return "not_object"

# %%
for sent in all_sents[:10]:
    for i in range(len(nlp(sent))):
        print(nlp(sent)[i], nlp(sent)[i].dep_, nlp(sent)[i].tag_, nlp(sent)[i].pos_, nlp(sent)[i].head, nlp(sent)[i].head.dep_, is_object(sent, i))
#         print(nlp(sent)[i], is_object(sent, i))
    print()
# Out:
# i nsubj PRP PRON looking ROOT not_object
# am aux VBP AUX looking ROOT not_object
# looking ROOT VBG VERB looking ROOT not_object
# for prep IN ADP looking ROOT not_object
# a det DT DET gloss pobj not_object
# black amod JJ ADJ gloss pobj object_modifier
# gloss pobj NN NOUN for prep object
# 33 nummod CD NUM inch compound object_modifier
# inch compound NN NOUN fireclay compound object_modifier
# fireclay compound NN NOUN sink appos object_modifier
# apron compound NN NOUN sink appos object_modifier
# sink appos NN NOUN gloss pobj object
#
# looking advcl VBG VERB hydrate ROOT not_object
# for prep IN ADP looking advcl not_object
# pre amod JJ ADJ addict pobj not_object
# workout compound NN NOUN pump compound not_object
# pump compound NN NOUN addict pobj not_object
# addict pobj NN NOUN for prep not_object
# instead advmod RB ADV of prep not_object
# of prep IN ADP looking advcl not_object
# karbolyn pobj NNP PROPN of prep not_object
# hydrate ROOT VBP VERB hydrate ROOT not_object
# with prep IN ADP hydrate ROOT not_object
# one pobj CD NUM with prep not_object
# is ccomp VBZ AUX hydrate ROOT not_object
# better acomp JJR ADJ is ccomp object_modifier
# ? punct . PUNCT hydrate ROOT not_object
#
# i nsubj PRP PRON need ROOT not_object
# need ROOT VBP VERB need ROOT not_object
# a det DT DET goof dobj not_object
# 48 nummod CD NUM inch compound object_modifier
# inch compound NN NOUN glass npadvmod object_modifier
# glass npadvmod NN NOUN sliding amod object_modifier
# sliding amod VBG VERB goof dobj object_modifier
# goof dobj NN NOUN need ROOT object
# and cc CC CCONJ goof dobj not_object
# a det DT DET system conj not_object
# shower compound NN NOUN system conj object_modifier
# pan compound NN NOUN system conj object_modifier
# system conj NN NOUN goof dobj object
# for prep IN ADP goof dobj not_object
# 500.99 pobj CD NUM for prep object_modifier
# or cc CC CCONJ 500.99 pobj not_object
# less conj JJR ADJ 500.99 pobj object_modifier
#
# hello intj UH INTJ have ROOT not_object
# , punct , PUNCT have ROOT not_object
# do aux VB AUX have ROOT not_object
# any nsubj DT PRON have ROOT not_object
# of prep IN ADP any nsubj not_object
# your poss PRP$ PRON stubs pobj not_object
# free amod JJ ADJ stubs pobj object_modifier
# standing amod VBG VERB stubs pobj object_modifier
# stubs pobj NNS NOUN of prep object
# have ROOT VBP VERB have ROOT not_object
# a det DT DET finish dobj not_object
# matte nmod NN NOUN finish dobj object_modifier
# white amod JJ ADJ finish dobj object_modifier
# finish dobj NN NOUN have ROOT object_modifier
# instead advmod RB ADV of cc not_object
# of cc IN ADP finish dobj not_object
# a det DT DET finish conj not_object
# glossy amod JJ ADJ finish conj object_modifier
# finish conj NN NOUN finish dobj object_modifier
# ? punct . PUNCT have ROOT not_object
#
# i nsubj PRP PRON looking ROOT not_object
# ' aux VBP AUX looking ROOT not_object
# m aux VBP AUX looking ROOT not_object
# looking ROOT VBG VERB looking ROOT not_object
# for prep IN ADP looking ROOT not_object
# a det DT DET mirror pobj not_object
# 24 nummod CD NUM inch compound object_modifier
# inch compound NN NOUN mirror pobj object_modifier
# white compound JJ ADJ mirror pobj object_modifier
# mirror pobj NN NOUN for prep object
# that nsubj WDT PRON freestanding relcl not_object
# is aux VBZ AUX freestanding relcl not_object
# freestanding relcl VBG VERB mirror pobj object_modifier
# and cc CC CCONJ freestanding relcl not_object
# reasonably advmod RB ADV priced conj object_modifier
# priced conj VBN VERB freestanding relcl object_modifier
# . punct . PUNCT looking ROOT not_object
#
# does aux VBZ AUX come ROOT not_object
# the det DT DET linen nsubj not_object
# linen nsubj NN NOUN come ROOT object
# and cc CC CCONJ linen nsubj not_object
# cotton compound NN NOUN cover conj object_modifier
# duvet compound NN NOUN cover conj object_modifier
# cover conj NN NOUN linen nsubj object
# come ROOT VBP VERB come ROOT not_object
# in prep IN ADP come ROOT not_object
# king pobj NN NOUN in prep object_modifier
# ? punct . PUNCT come ROOT not_object
#
# hi ROOT UH INTJ hi ROOT not_object
# there advmod RB ADV hi ROOT not_object
# . punct . PUNCT hi ROOT not_object
# i nsubj PRP PRON looking ROOT not_object
# ' aux VBP AUX looking ROOT not_object
# m aux VBP AUX looking ROOT not_object
# looking ROOT VBG VERB looking ROOT not_object
# to aux TO PART buy xcomp not_object
# buy xcomp VB VERB looking ROOT not_object
# some det DT DET blankets dobj not_object
# throw compound NN NOUN blankets dobj object_modifier
# blankets dobj NNS NOUN buy xcomp object
# . punct . PUNCT looking ROOT not_object
# your poss PRP$ PRON website nsubj not_object
# website nsubj NN NOUN states ROOT not_object
# states ROOT VBZ VERB states ROOT not_object
# that mark IN SCONJ is ccomp not_object
# the det DT DET underside nsubj not_object
# underside nsubj NN NOUN is ccomp object
# of prep IN ADP underside nsubj not_object
# the det DT DET throw pobj not_object
# double amod JJ ADJ throw pobj not_object
# wool npadvmod NN NOUN like amod not_object
# - punct HYPH PUNCT like amod not_object
# like amod JJ ADJ throw pobj object_modifier
# throw pobj NN NOUN of prep object_modifier
# is ccomp VBZ AUX states ROOT not_object
# very advmod RB ADV soft acomp object_modifier
# soft acomp JJ ADJ is ccomp object_modifier
# . punct . PUNCT states ROOT not_object
# i nsubj PRP PRON like ROOT not_object
# would aux MD AUX like ROOT not_object
# like ROOT VB VERB like ROOT not_object
# to aux TO PART know xcomp not_object
# know xcomp VB VERB like ROOT not_object
# if mark IN SCONJ is ccomp not_object
# the det DT DET side nsubj not_object
# wool nmod NN NOUN side nsubj not_object
# - punct HYPH PUNCT like prep not_object
# like prep IN ADP wool nmod not_object
# top amod JJ ADJ side nsubj object_modifier
# side nsubj NN NOUN is ccomp object
# is ccomp VBZ AUX know xcomp not_object
# soft acomp JJ ADJ is ccomp object_modifier
# as advmod RB ADV well advmod not_object
# well advmod RB ADV is ccomp not_object
# , punct , PUNCT know xcomp not_object
# or cc CC CCONJ like ROOT not_object
# if mark IN SCONJ is conj not_object
# it nsubj PRP PRON is conj not_object
# is conj VBZ AUX like ROOT not_object
# scratch attr NN NOUN is conj not_object
# . punct . PUNCT like ROOT not_object
# i nsubj PRP PRON have ROOT not_object
# have ROOT VBP VERB have ROOT not_object
# hypersensitive amod JJ ADJ skin dobj not_object
# skin dobj NN NOUN have ROOT not_object
# and cc CC CCONJ have ROOT not_object
# need conj VBP VERB have ROOT not_object
# a det DT DET blanket dobj not_object
# blanket dobj NN NOUN need conj object
# that nsubj WDT PRON irritated relcl not_object
# will aux MD AUX irritated relcl not_object
# not neg RB PART irritated relcl not_object
# irritated relcl VB VERB blanket dobj not_object
# me dobj PRP PRON irritated relcl not_object
# . punct . PUNCT have ROOT not_object
# thanks ROOT NNS NOUN thanks ROOT not_object
# . punct . PUNCT thanks ROOT not_object
#
# long amod JJ ADJ brown npadvmod not_object
# sharp amod JJ ADJ jacket compound not_object
# jacket compound NN NOUN brown npadvmod not_object
# dark amod NN NOUN brown npadvmod not_object
# brown npadvmod NN NOUN find ROOT not_object
# why advmod WRB SCONJ find ROOT not_object
# ca aux MD AUX find ROOT not_object
# n't neg RB PART find ROOT not_object
# i nsubj PRP PRON find ROOT not_object
# find ROOT VB VERB find ROOT not_object
# it dobj PRP PRON find ROOT not_object
# ? punct . PUNCT find ROOT not_object
#
# hello ROOT UH INTJ hello ROOT not_object
# . punct . PUNCT hello ROOT not_object
# i nsubj PRP PRON looking ROOT not_object
# ' aux VBP AUX looking ROOT not_object
# m aux VBP AUX looking ROOT not_object
# looking ROOT VBG VERB looking ROOT not_object
# for prep IN ADP looking ROOT not_object
# a det DT DET face pobj not_object
# soft amod JJ ADJ face pobj object_modifier
# open amod JJ ADJ face pobj object_modifier
# face pobj NN NOUN for prep object
# cardinal appos NN NOUN face pobj object
# w prep IN ADP cardinal appos not_object
# no det DT DET buttons pobj not_object
# buttons pobj NNS NOUN w prep object_modifier
# . punct . PUNCT looking ROOT not_object
#
# hi intj UH INTJ carry ROOT not_object
# do aux VBP AUX carry ROOT not_object
# you nsubj PRP PRON carry ROOT not_object
# carry ROOT VB VERB carry ROOT not_object
# any det DT DET oval compound not_object
# oval compound NN NOUN stubs dobj object_modifier
# stubs dobj VBZ VERB carry ROOT object
# in prep IN ADP carry ROOT not_object
# a det DT DET finish pobj not_object
# matte nmod NN NOUN finish pobj object_modifier
# white compound JJ ADJ finish pobj object_modifier
# finish pobj NN NOUN in prep object_modifier
# or cc CC CCONJ carry ROOT not_object
# not neg RB PART much conj not_object
# too advmod RB ADV much conj not_object
# much conj JJ ADJ carry ROOT not_object
# of prep IN ADP much conj not_object
# gloss pobj NN NOUN of prep not_object
# ? punct . PUNCT carry ROOT not_object
# i nsubj PRP PRON know ROOT not_object
# know ROOT VBP VERB know ROOT not_object
# they nsubj PRP PRON make ccomp not_object
# make ccomp VBP VERB know ROOT not_object
# solid amod JJ ADJ surface dobj object_modifier
# surface dobj NN NOUN make ccomp object
# but cc CC CCONJ surface dobj not_object
# higher amod JJR ADJ prices conj object_modifier
# prices conj NNS NOUN surface dobj object
# . punct . PUNCT know ROOT not_object
# thank ROOT VBP VERB thank ROOT not_object
# you dobj PRP PRON thank ROOT not_object
